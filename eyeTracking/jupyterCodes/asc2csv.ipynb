# %%
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Circle

# %%
import sys
sys.path.append('./ascData/PyGazeAnalyser-master/pygazeanalyser')
from edfreader import read_edf

# %%
dataName = input()
data = './ascData/'+ dataName + '.asc'
# Out:
# test

# %%
data_raw = read_edf(data, 'START', missing=0.0, debug=True)
type(data_raw), len(data_raw), type(data_raw[0]), data_raw[0].keys()
# Out:
# opening file './ascData/test.asc'
# reading file './ascData/test.asc'
# closing file './ascData/test.asc'
# trialstart 0
# line 'START	846091 	RIGHT	SAMPLES	EVENTS
# ' could not be parsed
# line 'PRESCALER	1
# ' could not be parsed
# line 'VPRESCALER	1
# ' could not be parsed
# line 'PUPIL	AREA
# ' could not be parsed
# line 'EVENTS	GAZE	RIGHT	RATE	 500.00	TRACKING	CR	FILTER	2
# ' could not be parsed
# line 'SAMPLES	GAZE	RIGHT	HTARGET	RATE	 500.00	TRACKING	CR	FILTER	2
# ' could not be parsed
# line 'INPUT	846091	120
# ' could not be parsed
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# blink start
# blink end
# blink start
# blink end
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# blink start
# blink end
# blink start
# blink end
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# saccade end
# fixation start
# fixation end
# saccade start
# blink start
# blink end
# blink start
# blink end
# saccade end
# line 'END	1526762 	SAMPLES	EVENTS	RES	  46.82	  46.44
# ' could not be parsed
# trialend 0; 340336 samples found
# line 'INPUT	1526773	120
# ' could not be parsed
# (list, 1, dict, dict_keys(['x', 'y', 'size', 'time', 'trackertime', 'events']))

# %%
df = pd.DataFrame(columns = ['Trial', 'X', 'Y', 'Start', 'End'])
for i in range(len(data_raw)):
    trial = i+1
    for j in range(len(data_raw[i]['events']['Efix'])):
        row = {'Trial':int(i), 'X':0, 'Y':0, 'Start':0, 'End':0}
        
        X = data_raw[i]['events']['Efix'][j][3]
        Y = data_raw[i]['events']['Efix'][j][4]
        start = data_raw[i]['events']['Efix'][j][0]
        end = data_raw[i]['events']['Efix'][j][1]
        
        row['X'] = X
        row['Y'] = Y
        row['Start'] = start
        row['End'] = end
        
        df = df.append(row, ignore_index=True)

df.Trial = df.Trial.astype(int)
                   
df
# Out:
#      Trial       X       Y      Start        End
# 0        0   956.5   562.5   846095.0   846245.0
# 1        0  -553.4   884.4   846333.0   846597.0
# 2        0  1010.0   597.4   847115.0   847303.0
# 3        0  -681.2  1008.9   847395.0   847621.0
# 4        0  -685.8  1463.2   847677.0   847819.0
# ..     ...     ...     ...        ...        ...
# 714      0   929.0   488.9  1524317.0  1525281.0
# 715      0   763.8   358.7  1525305.0  1525441.0
# 716      0   893.8   303.5  1525463.0  1525595.0
# 717      0   383.4   223.7  1525635.0  1525819.0
# 718      0   292.1   221.2  1525839.0  1525961.0
#
# [719 rows x 5 columns]

# %%
asci_data = open(data, 'r')
lines = []
for line in asci_data:
    lines.append(line)

# %%
for idx, line in enumerate(lines):
    if 'TimeStamp' in line:
        time_line = lines[idx-1].split()
        break

eyelink_time = int(time_line[1])
eyelink_time

unix_time_ml = int(float(time_line[-1]) * 1000)
unix_time_ml

diff = unix_time_ml - eyelink_time
diff

df['Start'] = (df.Start + diff) / 1000
df['End'] = (df.End + diff) / 1000
df.Start = df.Start.apply(lambda x: '%.3f' % x)
df.End = df.End.apply(lambda x: '%.3f' % x)

df
# Out:
#      Trial       X       Y           Start             End
# 0        0   956.5   562.5  1636719092.920  1636719093.070
# 1        0  -553.4   884.4  1636719093.158  1636719093.422
# 2        0  1010.0   597.4  1636719093.940  1636719094.128
# 3        0  -681.2  1008.9  1636719094.220  1636719094.446
# 4        0  -685.8  1463.2  1636719094.502  1636719094.644
# ..     ...     ...     ...             ...             ...
# 714      0   929.0   488.9  1636719771.142  1636719772.106
# 715      0   763.8   358.7  1636719772.130  1636719772.266
# 716      0   893.8   303.5  1636719772.288  1636719772.420
# 717      0   383.4   223.7  1636719772.460  1636719772.644
# 718      0   292.1   221.2  1636719772.664  1636719772.786
#
# [719 rows x 5 columns]

# %%
df.to_csv('./data/el_data/el_events/' + dataName + '_events.csv', index = False)

# %%
df_all = pd.DataFrame(columns = ['X', 'Y', 'Time'])
df_all

x = []
y = []
time = []

for i in range(len(data_raw)):
    x = x + list(data_raw[i]['x'])
    y = y + list(data_raw[i]['y'])
    time = time + list(data_raw[i]['trackertime'])

df_all.X = x
df_all.Y = y
df_all.Time = time

# df_all
df_all.Time = (df_all.Time + diff) / 1000
# df_all.Time = df_all.Time.apply(lambda x: '%.3f' % x)

df_all
# Out:
#             X      Y          Time
# 0       953.4  565.1  1.636719e+09
# 1       953.2  564.3  1.636719e+09
# 2       953.0  564.1  1.636719e+09
# 3       952.7  564.1  1.636719e+09
# 4       952.2  564.1  1.636719e+09
# ...       ...    ...           ...
# 340331 -617.6  732.5  1.636720e+09
# 340332 -616.7  735.0  1.636720e+09
# 340333 -617.5  736.7  1.636720e+09
# 340334 -619.3  738.4  1.636720e+09
# 340335 -621.5  740.2  1.636720e+09
#
# [340336 rows x 3 columns]

# %%
df_all.to_csv('./data/el_data/' + dataName + '.csv', index = False)
